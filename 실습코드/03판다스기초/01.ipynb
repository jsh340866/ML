# %%
import pandas as pd
menu = pd.Series(['비빔밥', '김치찌개', '된장찌개'])
price = pd.Series([10000, 9000, 8000])
# menu
price
# Out:
# 0    10000
# 1     9000
# 2     8000
# dtype: int64

# %%
df_from_series = pd.DataFrame({'메뉴': menu, '가격': price})
df_from_series
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
df = pd.DataFrame({
    '메뉴':  ['비빔밥', '김치찌개', '된장찌개'],
    '가격':  [10000, 9000, 8000],
    '원산지': ['국내산', '국내산', '국내산']
})
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9000  국내산
# 2  된장찌개   8000  국내산

# %%
menu_series = df['메뉴']     # Series
menu_df = df[['메뉴']]       # DataFrame (대괄호 2개)
# menu_series
menu_df
# Out:
#      메뉴
# 0   비빔밥
# 1  김치찌개
# 2  된장찌개

# %%
cols = ['메뉴', '가격']
# df[cols]
df[['메뉴','가격']]
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000
# 2  된장찌개   8000

# %%
print('df          :', type(df))
print("df['가격']   :", type(df['가격']))     # Series
print("df[['가격']] :", type(df[['가격']]))   # DataFrame
# Out:
# df          : <class 'pandas.core.frame.DataFrame'>
# df['가격']   : <class 'pandas.core.series.Series'>
# df[['가격']] : <class 'pandas.core.frame.DataFrame'>

# %%
# df
# print(df.loc[0])          # 인덱스 0 행 전체
df.loc[df['가격'] >= 9000, ['메뉴', '가격']]   # 가격 9000 이상
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000

# %%
print(df.iloc[0])         # 0번째 행
# Out:
# 메뉴       비빔밥
# 가격     10000
# 원산지      국내산
# Name: 0, dtype: object

# %%
df.iloc[0:2, 0:2]        # 앞 2행, 앞 2열
# Out:
#      메뉴     가격
# 0   비빔밥  10000
# 1  김치찌개   9000

# %%
df['가격']

df['할인가'] = (df['가격'] * 0.9).astype(int)   # 10% 할인 열
df
# Out:
#      메뉴     가격  원산지   할인가
# 0   비빔밥  10000  국내산  9000
# 1  김치찌개   9000  국내산  8100
# 2  된장찌개   8000  국내산  7200

# %%
df.loc[df['메뉴'] == '김치찌개', '가격'] = 9500   # 김치찌개 가격 변경
df
# Out:
#      메뉴     가격  원산지   할인가
# 0   비빔밥  10000  국내산  9000
# 1  김치찌개   9500  국내산  8100
# 2  된장찌개   8000  국내산  7200

# %%
df = df.drop(columns=['할인가'])
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9500  국내산
# 2  된장찌개   8000  국내산

# %%
df.sort_values(by='가격', ascending=True)   # 가격 내림차순, ascending=False 내림차순, ascending=True 오름차순
# Out:
#      메뉴     가격  원산지
# 2  된장찌개   8000  국내산
# 1  김치찌개   9500  국내산
# 0   비빔밥  10000  국내산

# %%
df
# Out:
#      메뉴     가격  원산지
# 0   비빔밥  10000  국내산
# 1  김치찌개   9500  국내산
# 2  된장찌개   8000  국내산

# %%
print((df['원산지'] == '국내산') & (df['가격'] >= 9000))
# df[(df['원산지'] == '국내산') & (df['가격'] >= 9000)]
# Out:
# 0     True
# 1     True
# 2    False
# dtype: bool

# %%
df.rename(columns={'메뉴': 'menu', '가격': 'price', '원산지': 'origin'})
# Out:
#    menu  price origin
# 0   비빔밥  10000    국내산
# 1  김치찌개   9500    국내산
# 2  된장찌개   8000    국내산
